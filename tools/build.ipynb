# %%
import numpy as np
import pandas as pd

# %%
# dataset grezzo
df = pd.read_csv(
    "dataset.csv",
    parse_dates=[
        "data", "pubblicazione", "popolazione_giorno",
        "diagnosi_start", "diagnosi_end",
        "ricoveri_start", "ricoveri_end",
        "intensive_start", "intensive_end",
        "decessi_start", "decessi_end"
    ],
    dtype={
        'popolazione': np.object,
        'diagnosi': np.object,
        'ricoveri': np.object,
        'intensive': np.object,
        'decessi': np.object,
    }
)
df
# Out:
#           data pubblicazione  \
# 0   2021-11-03    2021-11-05
# 1   2021-11-03    2021-11-05
# 2   2021-11-03    2021-11-05
# 3   2021-11-03    2021-11-05
# 4   2021-11-03    2021-11-05
# ..         ...           ...
# 199 2021-07-14    2021-07-16
# 200 2021-07-14    2021-07-16
# 201 2021-07-14    2021-07-16
# 202 2021-07-14    2021-07-16
# 203 2021-07-14    2021-07-16
#
#                                                    url fascia  \
# 0    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 1    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 2    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 3    https://www.epicentro.iss.it/coronavirus/bolle...  40-59
# 4    https://www.epicentro.iss.it/coronavirus/bolle...  40-59
# ..                                                 ...    ...
# 199  https://www.epicentro.iss.it/coronavirus/bolle...  60-79
# 200  https://www.epicentro.iss.it/coronavirus/bolle...  60-79
# 201  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 202  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 203  https://www.epicentro.iss.it/coronavirus/bolle...    80+
#
#                   vaccino popolazione diagnosi ricoveri intensive decessi  \
# 0           non vaccinati   3.851.600   16.805      486        30       4
# 1    vaccinati incompleto   1.387.907    1.478       31         2       3
# 2      vaccinati completo  12.196.048   10.123       90         0       3
# 3           non vaccinati   3.246.622   12.924      940        99      53
# 4    vaccinati incompleto     876.762    1.163       32         2       2
# ..                    ...         ...      ...      ...       ...     ...
# 199  vaccinati incompleto   5.415.352    1.067      151        17      46
# 200    vaccinati completo   4.905.555      568       70         2      12
# 201         non vaccinati     460.790      302      168        21     147
# 202  vaccinati incompleto     281.202       58       27         0      21
# 203    vaccinati completo   3.812.115      487      142         5      55
#
#     popolazione_giorno diagnosi_start diagnosi_end ricoveri_start  \
# 0           2021-10-16     2021-10-01   2021-10-31     2021-09-24
# 1           2021-10-16     2021-10-01   2021-10-31     2021-09-24
# 2           2021-10-16     2021-10-01   2021-10-31     2021-09-24
# 3           2021-10-16     2021-10-01   2021-10-31     2021-09-24
# 4           2021-10-16     2021-10-01   2021-10-31     2021-09-24
# ..                 ...            ...          ...            ...
# 199         2021-06-26     2021-06-11   2021-07-11     2021-06-04
# 200         2021-06-26     2021-06-11   2021-07-11     2021-06-04
# 201         2021-06-26     2021-06-11   2021-07-11     2021-06-04
# 202         2021-06-26     2021-06-11   2021-07-11     2021-06-04
# 203         2021-06-26     2021-06-11   2021-07-11     2021-06-04
#
#     ricoveri_end intensive_start intensive_end decessi_start decessi_end
# 0     2021-10-24      2021-09-24    2021-10-24    2021-09-10  2021-10-10
# 1     2021-10-24      2021-09-24    2021-10-24    2021-09-10  2021-10-10
# 2     2021-10-24      2021-09-24    2021-10-24    2021-09-10  2021-10-10
# 3     2021-10-24      2021-09-24    2021-10-24    2021-09-10  2021-10-10
# 4     2021-10-24      2021-09-24    2021-10-24    2021-09-10  2021-10-10
# ..           ...             ...           ...           ...         ...
# 199   2021-07-04      2021-06-04    2021-07-04    2021-05-21  2021-06-20
# 200   2021-07-04      2021-06-04    2021-07-04    2021-05-21  2021-06-20
# 201   2021-07-04      2021-06-04    2021-07-04    2021-05-21  2021-06-20
# 202   2021-07-04      2021-06-04    2021-07-04    2021-05-21  2021-06-20
# 203   2021-07-04      2021-06-04    2021-07-04    2021-05-21  2021-06-20
#
# [204 rows x 19 columns]

# %%
# integer casting
df["popolazione"] = df.popolazione.str.replace(".", "", regex=False).astype(int)
df["diagnosi"] = df.diagnosi.str.replace(".", "", regex=False).astype(int)
df["ricoveri"] = df.ricoveri.str.replace(".", "", regex=False).astype(int)
df["intensive"] = df.intensive.str.replace(".", "", regex=False).astype(int)
df["decessi"] = df.decessi.str.replace(".", "", regex=False).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   data                204 non-null    datetime64[ns]
#  1   pubblicazione       204 non-null    datetime64[ns]
#  2   url                 204 non-null    object
#  3   fascia              204 non-null    object
#  4   vaccino             204 non-null    object
#  5   popolazione         204 non-null    int64
#  6   diagnosi            204 non-null    int64
#  7   ricoveri            204 non-null    int64
#  8   intensive           204 non-null    int64
#  9   decessi             204 non-null    int64
#  10  popolazione_giorno  204 non-null    datetime64[ns]
#  11  diagnosi_start      204 non-null    datetime64[ns]
#  12  diagnosi_end        204 non-null    datetime64[ns]
#  13  ricoveri_start      204 non-null    datetime64[ns]
#  14  ricoveri_end        204 non-null    datetime64[ns]
#  15  intensive_start     204 non-null    datetime64[ns]
#  16  intensive_end       204 non-null    datetime64[ns]
#  17  decessi_start       204 non-null    datetime64[ns]
#  18  decessi_end         204 non-null    datetime64[ns]
# dtypes: datetime64[ns](11), int64(5), object(3)
# memory usage: 30.4+ KB

# %%
# popolazione totale per data e fascia
popolazione = df.groupby(["data", "fascia"])[["popolazione"]].sum().reset_index()
popolazione
# Out:
#          data fascia  popolazione
# 0  2021-07-14  12-39     17435555
# 1  2021-07-14  40-59     18447460
# 2  2021-07-14  60-79     13572779
# 3  2021-07-14    80+      4554107
# 4  2021-07-21  12-39     17435555
# ..        ...    ...          ...
# 63 2021-10-27    80+      4563500
# 64 2021-11-03  12-39     17435555
# 65 2021-11-03  40-59     18438105
# 66 2021-11-03  60-79     13572779
# 67 2021-11-03    80+      4563500
#
# [68 rows x 3 columns]

# %%
# aggiunta popolazione totale per fascia e data
for data in df.data.unique():
    for fascia in df.fascia.unique():
        _pop = popolazione.loc[(popolazione.data==data)&(popolazione.fascia==fascia), "popolazione"].values[0]
        df.loc[(df.data==data)&(df.fascia==fascia), "totale"] = _pop
df["totale"] = df.totale.astype(int)

# %%
# calcolo percentuale di popolazione per data, fascia e stato vaccinale
df["percentuale_popolazione"] = df.popolazione / df.totale

# %%
# ordinamento per data e fascia
df.sort_values(by=["data", "fascia"], inplace=True)

# %%
# calcolo dei tassi per data, fascia e stato vaccinale
for y in ["diagnosi", "ricoveri", "intensive", "decessi"]:
    df[f"percentuale_{y}"] = df[y] / df.popolazione

# %%
# salvataggio report completo
df.to_csv("../reports_iss_vaccini.csv", index=False)

# %%
# controllo del file salvato
df_check = pd.read_csv(
    "../reports_iss_vaccini.csv",
    parse_dates=[
        "data", "pubblicazione", "popolazione_giorno",
        "diagnosi_start", "diagnosi_end",
        "ricoveri_start", "ricoveri_end",
        "intensive_start", "intensive_end",
        "decessi_start", "decessi_end"
    ]
)
df_check
# Out:
#           data pubblicazione  \
# 0   2021-07-14    2021-07-16
# 1   2021-07-14    2021-07-16
# 2   2021-07-14    2021-07-16
# 3   2021-07-14    2021-07-16
# 4   2021-07-14    2021-07-16
# ..         ...           ...
# 199 2021-11-03    2021-11-05
# 200 2021-11-03    2021-11-05
# 201 2021-11-03    2021-11-05
# 202 2021-11-03    2021-11-05
# 203 2021-11-03    2021-11-05
#
#                                                    url fascia  \
# 0    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 1    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 2    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 3    https://www.epicentro.iss.it/coronavirus/bolle...  40-59
# 4    https://www.epicentro.iss.it/coronavirus/bolle...  40-59
# ..                                                 ...    ...
# 199  https://www.epicentro.iss.it/coronavirus/bolle...  60-79
# 200  https://www.epicentro.iss.it/coronavirus/bolle...  60-79
# 201  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 202  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 203  https://www.epicentro.iss.it/coronavirus/bolle...    80+
#
#                   vaccino  popolazione  diagnosi  ricoveri  intensive  \
# 0           non vaccinati     14011891     13549       513         13
# 1    vaccinati incompleto      1815895      1243        11          0
# 2      vaccinati completo      1607769       528         4          0
# 3           non vaccinati      9340510      5747       779         66
# 4    vaccinati incompleto      5502988      1586        51          3
# ..                    ...          ...       ...       ...        ...
# 199  vaccinati incompleto       295045       471        49          7
# 200    vaccinati completo     11928111     11006       737         82
# 201         non vaccinati       235904      1055       375         16
# 202  vaccinati incompleto        93709        95        33          0
# 203    vaccinati completo      4233887      4591       991         44
#
#      decessi  ... intensive_start intensive_end decessi_start decessi_end  \
# 0          7  ...      2021-06-04    2021-07-04    2021-05-21  2021-06-20
# 1          1  ...      2021-06-04    2021-07-04    2021-05-21  2021-06-20
# 2          0  ...      2021-06-04    2021-07-04    2021-05-21  2021-06-20
# 3         45  ...      2021-06-04    2021-07-04    2021-05-21  2021-06-20
# 4          4  ...      2021-06-04    2021-07-04    2021-05-21  2021-06-20
# ..       ...  ...             ...           ...           ...         ...
# 199        7  ...      2021-09-24    2021-10-24    2021-09-10  2021-10-10
# 200      102  ...      2021-09-24    2021-10-24    2021-09-10  2021-10-10
# 201      190  ...      2021-09-24    2021-10-24    2021-09-10  2021-10-10
# 202       15  ...      2021-09-24    2021-10-24    2021-09-10  2021-10-10
# 203      309  ...      2021-09-24    2021-10-24    2021-09-10  2021-10-10
#
#        totale percentuale_popolazione percentuale_diagnosi  \
# 0    17435555                0.803639             0.000967
# 1    17435555                0.104149             0.000685
# 2    17435555                0.092212             0.000328
# 3    18447460                0.506330             0.000615
# 4    18447460                0.298306             0.000288
# ..        ...                     ...                  ...
# 199  13572779                0.021738             0.001596
# 200  13572779                0.878826             0.000923
# 201   4563500                0.051694             0.004472
# 202   4563500                0.020534             0.001014
# 203   4563500                0.927772             0.001084
#
#     percentuale_ricoveri percentuale_intensive  percentuale_decessi
# 0               0.000037          9.277834e-07         4.995757e-07
# 1               0.000006          0.000000e+00         5.506926e-07
# 2               0.000002          0.000000e+00         0.000000e+00
# 3               0.000083          7.065995e-06         4.817724e-06
# 4               0.000009          5.451584e-07         7.268778e-07
# ..                   ...                   ...                  ...
# 199             0.000166          2.372519e-05         2.372519e-05
# 200             0.000062          6.874517e-06         8.551228e-06
# 201             0.001590          6.782420e-05         8.054124e-04
# 202             0.000352          0.000000e+00         1.600700e-04
# 203             0.000234          1.039234e-05         7.298258e-05
#
# [204 rows x 25 columns]

# %%
df_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   data                     204 non-null    datetime64[ns]
#  1   pubblicazione            204 non-null    datetime64[ns]
#  2   url                      204 non-null    object
#  3   fascia                   204 non-null    object
#  4   vaccino                  204 non-null    object
#  5   popolazione              204 non-null    int64
#  6   diagnosi                 204 non-null    int64
#  7   ricoveri                 204 non-null    int64
#  8   intensive                204 non-null    int64
#  9   decessi                  204 non-null    int64
#  10  popolazione_giorno       204 non-null    datetime64[ns]
#  11  diagnosi_start           204 non-null    datetime64[ns]
#  12  diagnosi_end             204 non-null    datetime64[ns]
#  13  ricoveri_start           204 non-null    datetime64[ns]
#  14  ricoveri_end             204 non-null    datetime64[ns]
#  15  intensive_start          204 non-null    datetime64[ns]
#  16  intensive_end            204 non-null    datetime64[ns]
#  17  decessi_start            204 non-null    datetime64[ns]
#  18  decessi_end              204 non-null    datetime64[ns]
#  19  totale                   204 non-null    int64
#  20  percentuale_popolazione  204 non-null    float64
#  21  percentuale_diagnosi     204 non-null    float64
#  22  percentuale_ricoveri     204 non-null    float64
#  23  percentuale_intensive    204 non-null    float64
#  24  percentuale_decessi      204 non-null    float64
# dtypes: datetime64[ns](11), float64(5), int64(6), object(3)
# memory usage: 40.0+ KB
