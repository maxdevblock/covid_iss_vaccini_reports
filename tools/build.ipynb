# %%
import numpy as np
import pandas as pd

# %%
# dataset grezzo
df = pd.read_csv(
    "dataset.csv",
    parse_dates=[
        "data", "pubblicazione", "popolazione_giorno",
        "diagnosi_start", "diagnosi_end",
        "ricoveri_start", "ricoveri_end",
        "intensive_start", "intensive_end",
        "decessi_start", "decessi_end"
    ],
    dtype={
        'popolazione': np.object,
        'diagnosi': np.object,
        'ricoveri': np.object,
        'intensive': np.object,
        'decessi': np.object,
    }
)
df
# Out:
#           data pubblicazione  \
# 0   2021-12-28    2021-12-31
# 1   2021-12-28    2021-12-31
# 2   2021-12-28    2021-12-31
# 3   2021-12-28    2021-12-31
# 4   2021-12-28    2021-12-31
# ..         ...           ...
# 359 2021-07-14    2021-07-16
# 360 2021-07-14    2021-07-16
# 361 2021-07-14    2021-07-16
# 362 2021-07-14    2021-07-16
# 363 2021-07-14    2021-07-16
#
#                                                    url fascia  \
# 0    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 1    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 2    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 3    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 4    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# ..                                                 ...    ...
# 359  https://www.epicentro.iss.it/coronavirus/bolle...  60-79
# 360  https://www.epicentro.iss.it/coronavirus/bolle...  60-79
# 361  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 362  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 363  https://www.epicentro.iss.it/coronavirus/bolle...    80+
#
#                                      vaccino popolazione diagnosi ricoveri  \
# 0                              non vaccinati   2.892.447   79.859      684
# 1                       vaccinati incompleto     725.242    7.410       36
# 2               vaccinati completo <= 4 mesi   8.126.842   67.245      177
# 3                vaccinati completo > 4 mesi   5.268.071   90.094      140
# 4    vaccinati completo + aggiuntiva/booster     423.663    5.125        8
# ..                                       ...         ...      ...      ...
# 359                     vaccinati incompleto   5.415.352    1.067      151
# 360                       vaccinati completo   4.905.555      568       70
# 361                            non vaccinati     460.790      302      168
# 362                     vaccinati incompleto     281.202       58       27
# 363                       vaccinati completo   3.812.115      487      142
#
#     intensive decessi popolazione_giorno diagnosi_start diagnosi_end  \
# 0          39       7         2021-12-11     2021-11-26   2021-12-26
# 1           1       0         2021-12-11     2021-11-26   2021-12-26
# 2           5       1         2021-12-11     2021-11-26   2021-12-26
# 3           4       1         2021-12-11     2021-11-26   2021-12-26
# 4           0       0         2021-12-11     2021-11-26   2021-12-26
# ..        ...     ...                ...            ...          ...
# 359        17      46         2021-06-26     2021-06-11   2021-07-11
# 360         2      12         2021-06-26     2021-06-11   2021-07-11
# 361        21     147         2021-06-26     2021-06-11   2021-07-11
# 362         0      21         2021-06-26     2021-06-11   2021-07-11
# 363         5      55         2021-06-26     2021-06-11   2021-07-11
#
#     ricoveri_start ricoveri_end intensive_start intensive_end decessi_start  \
# 0       2021-11-12   2021-12-12      2021-11-12    2021-12-12    2021-11-05
# 1       2021-11-12   2021-12-12      2021-11-12    2021-12-12    2021-11-05
# 2       2021-11-12   2021-12-12      2021-11-12    2021-12-12    2021-11-05
# 3       2021-11-12   2021-12-12      2021-11-12    2021-12-12    2021-11-05
# 4       2021-11-12   2021-12-12      2021-11-12    2021-12-12    2021-11-05
# ..             ...          ...             ...           ...           ...
# 359     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 360     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 361     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 362     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 363     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
#
#     decessi_end
# 0    2021-12-05
# 1    2021-12-05
# 2    2021-12-05
# 3    2021-12-05
# 4    2021-12-05
# ..          ...
# 359  2021-06-20
# 360  2021-06-20
# 361  2021-06-20
# 362  2021-06-20
# 363  2021-06-20
#
# [364 rows x 19 columns]

# %%
# integer casting
df["popolazione"] = df.popolazione.str.replace(".", "", regex=False).astype(int)
df["diagnosi"] = df.diagnosi.str.replace(".", "", regex=False).astype(int)
df["ricoveri"] = df.ricoveri.str.replace(".", "", regex=False).astype(int)
df["intensive"] = df.intensive.str.replace(".", "", regex=False).astype(int)
df["decessi"] = df.decessi.str.replace(".", "", regex=False).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   data                364 non-null    datetime64[ns]
#  1   pubblicazione       364 non-null    datetime64[ns]
#  2   url                 364 non-null    object
#  3   fascia              364 non-null    object
#  4   vaccino             364 non-null    object
#  5   popolazione         364 non-null    int64
#  6   diagnosi            364 non-null    int64
#  7   ricoveri            364 non-null    int64
#  8   intensive           364 non-null    int64
#  9   decessi             364 non-null    int64
#  10  popolazione_giorno  364 non-null    datetime64[ns]
#  11  diagnosi_start      364 non-null    datetime64[ns]
#  12  diagnosi_end        364 non-null    datetime64[ns]
#  13  ricoveri_start      364 non-null    datetime64[ns]
#  14  ricoveri_end        364 non-null    datetime64[ns]
#  15  intensive_start     364 non-null    datetime64[ns]
#  16  intensive_end       364 non-null    datetime64[ns]
#  17  decessi_start       364 non-null    datetime64[ns]
#  18  decessi_end         364 non-null    datetime64[ns]
# dtypes: datetime64[ns](11), int64(5), object(3)
# memory usage: 54.2+ KB

# %%
# popolazione totale per data e fascia
popolazione = df.groupby(["data", "fascia"])[["popolazione"]].sum().reset_index()
popolazione
# Out:
#          data fascia  popolazione
# 0  2021-07-14  12-39     17435555
# 1  2021-07-14  40-59     18447460
# 2  2021-07-14  60-79     13572779
# 3  2021-07-14    80+      4554107
# 4  2021-07-21  12-39     17435555
# ..        ...    ...          ...
# 95 2021-12-21    80+      4569709
# 96 2021-12-28  12-39     17436265
# 97 2021-12-28  40-59     18431602
# 98 2021-12-28  60-79     13572008
# 99 2021-12-28    80+      4570070
#
# [100 rows x 3 columns]

# %%
# aggiunta popolazione totale per fascia e data
for data in df.data.unique():
    for fascia in df.fascia.unique():
        _pop = popolazione.loc[(popolazione.data==data)&(popolazione.fascia==fascia), "popolazione"].values[0]
        df.loc[(df.data==data)&(df.fascia==fascia), "totale"] = _pop
df["totale"] = df.totale.astype(int)

# %%
# calcolo percentuale di popolazione per data, fascia e stato vaccinale
df["percentuale_popolazione"] = df.popolazione / df.totale

# %%
# ordinamento per data e fascia
df.sort_values(by=["data", "fascia"], inplace=True)

# %%
# calcolo dei tassi per data, fascia e stato vaccinale
for y in ["diagnosi", "ricoveri", "intensive", "decessi"]:
    df[f"percentuale_{y}"] = df[y] / df.popolazione

# %%
# salvataggio report completo
df.to_csv("../reports_iss_vaccini.csv", index=False)

# %%
# controllo del file salvato
df_check = pd.read_csv(
    "../reports_iss_vaccini.csv",
    parse_dates=[
        "data", "pubblicazione", "popolazione_giorno",
        "diagnosi_start", "diagnosi_end",
        "ricoveri_start", "ricoveri_end",
        "intensive_start", "intensive_end",
        "decessi_start", "decessi_end"
    ]
)
df_check
# Out:
#           data pubblicazione  \
# 0   2021-07-14    2021-07-16
# 1   2021-07-14    2021-07-16
# 2   2021-07-14    2021-07-16
# 3   2021-07-14    2021-07-16
# 4   2021-07-14    2021-07-16
# ..         ...           ...
# 359 2021-12-28    2021-12-31
# 360 2021-12-28    2021-12-31
# 361 2021-12-28    2021-12-31
# 362 2021-12-28    2021-12-31
# 363 2021-12-28    2021-12-31
#
#                                                    url fascia  \
# 0    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 1    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 2    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 3    https://www.epicentro.iss.it/coronavirus/bolle...  40-59
# 4    https://www.epicentro.iss.it/coronavirus/bolle...  40-59
# ..                                                 ...    ...
# 359  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 360  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 361  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 362  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 363  https://www.epicentro.iss.it/coronavirus/bolle...    80+
#
#                                      vaccino  popolazione  diagnosi  ricoveri  \
# 0                              non vaccinati     14011891     13549       513
# 1                       vaccinati incompleto      1815895      1243        11
# 2                         vaccinati completo      1607769       528         4
# 3                              non vaccinati      9340510      5747       779
# 4                       vaccinati incompleto      5502988      1586        51
# ..                                       ...          ...       ...       ...
# 359                            non vaccinati       209075      4299      1231
# 360                     vaccinati incompleto        81702       393       113
# 361             vaccinati completo <= 4 mesi       123583       427       102
# 362              vaccinati completo > 4 mesi      1939660     10598      2442
# 363  vaccinati completo + aggiuntiva/booster      2216050      3797       212
#
#      intensive  decessi  ... intensive_start intensive_end decessi_start  \
# 0           13        7  ...      2021-06-04    2021-07-04    2021-05-21
# 1            0        1  ...      2021-06-04    2021-07-04    2021-05-21
# 2            0        0  ...      2021-06-04    2021-07-04    2021-05-21
# 3           66       45  ...      2021-06-04    2021-07-04    2021-05-21
# 4            3        4  ...      2021-06-04    2021-07-04    2021-05-21
# ..         ...      ...  ...             ...           ...           ...
# 359         67      481  ...      2021-11-12    2021-12-12    2021-11-05
# 360          3       44  ...      2021-11-12    2021-12-12    2021-11-05
# 361          6       38  ...      2021-11-12    2021-12-12    2021-11-05
# 362         79      757  ...      2021-11-12    2021-12-12    2021-11-05
# 363          6       40  ...      2021-11-12    2021-12-12    2021-11-05
#
#     decessi_end    totale percentuale_popolazione percentuale_diagnosi  \
# 0    2021-06-20  17435555                0.803639             0.000967
# 1    2021-06-20  17435555                0.104149             0.000685
# 2    2021-06-20  17435555                0.092212             0.000328
# 3    2021-06-20  18447460                0.506330             0.000615
# 4    2021-06-20  18447460                0.298306             0.000288
# ..          ...       ...                     ...                  ...
# 359  2021-12-05   4570070                0.045749             0.020562
# 360  2021-12-05   4570070                0.017878             0.004810
# 361  2021-12-05   4570070                0.027042             0.003455
# 362  2021-12-05   4570070                0.424427             0.005464
# 363  2021-12-05   4570070                0.484905             0.001713
#
#     percentuale_ricoveri percentuale_intensive  percentuale_decessi
# 0               0.000037          9.277834e-07         4.995757e-07
# 1               0.000006          0.000000e+00         5.506926e-07
# 2               0.000002          0.000000e+00         0.000000e+00
# 3               0.000083          7.065995e-06         4.817724e-06
# 4               0.000009          5.451584e-07         7.268778e-07
# ..                   ...                   ...                  ...
# 359             0.005888          3.204592e-04         2.300610e-03
# 360             0.001383          3.671881e-05         5.385425e-04
# 361             0.000825          4.855037e-05         3.074857e-04
# 362             0.001259          4.072879e-05         3.902746e-04
# 363             0.000096          2.707520e-06         1.805013e-05
#
# [364 rows x 25 columns]

# %%
df_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   data                     364 non-null    datetime64[ns]
#  1   pubblicazione            364 non-null    datetime64[ns]
#  2   url                      364 non-null    object
#  3   fascia                   364 non-null    object
#  4   vaccino                  364 non-null    object
#  5   popolazione              364 non-null    int64
#  6   diagnosi                 364 non-null    int64
#  7   ricoveri                 364 non-null    int64
#  8   intensive                364 non-null    int64
#  9   decessi                  364 non-null    int64
#  10  popolazione_giorno       364 non-null    datetime64[ns]
#  11  diagnosi_start           364 non-null    datetime64[ns]
#  12  diagnosi_end             364 non-null    datetime64[ns]
#  13  ricoveri_start           364 non-null    datetime64[ns]
#  14  ricoveri_end             364 non-null    datetime64[ns]
#  15  intensive_start          364 non-null    datetime64[ns]
#  16  intensive_end            364 non-null    datetime64[ns]
#  17  decessi_start            364 non-null    datetime64[ns]
#  18  decessi_end              364 non-null    datetime64[ns]
#  19  totale                   364 non-null    int64
#  20  percentuale_popolazione  364 non-null    float64
#  21  percentuale_diagnosi     364 non-null    float64
#  22  percentuale_ricoveri     364 non-null    float64
#  23  percentuale_intensive    364 non-null    float64
#  24  percentuale_decessi      364 non-null    float64
# dtypes: datetime64[ns](11), float64(5), int64(6), object(3)
# memory usage: 71.2+ KB
