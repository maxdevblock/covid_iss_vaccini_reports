# %%
import numpy as np
import pandas as pd

# %%
# dataset grezzo
df = pd.read_csv(
    "dataset.csv",
    parse_dates=[
        "data", "pubblicazione", "popolazione_giorno",
        "diagnosi_start", "diagnosi_end",
        "ricoveri_start", "ricoveri_end",
        "intensive_start", "intensive_end",
        "decessi_start", "decessi_end"
    ],
    dtype={
        'popolazione': np.object,
        'diagnosi': np.object,
        'ricoveri': np.object,
        'intensive': np.object,
        'decessi': np.object,
    }
)
df
# Out:
#           data pubblicazione  \
# 0   2021-12-01    2021-12-03
# 1   2021-12-01    2021-12-03
# 2   2021-12-01    2021-12-03
# 3   2021-12-01    2021-12-03
# 4   2021-12-01    2021-12-03
# ..         ...           ...
# 279 2021-07-14    2021-07-16
# 280 2021-07-14    2021-07-16
# 281 2021-07-14    2021-07-16
# 282 2021-07-14    2021-07-16
# 283 2021-07-14    2021-07-16
#
#                                                    url fascia  \
# 0    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 1    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 2    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 3    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 4    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# ..                                                 ...    ...
# 279  https://www.epicentro.iss.it/coronavirus/bolle...  60-79
# 280  https://www.epicentro.iss.it/coronavirus/bolle...  60-79
# 281  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 282  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 283  https://www.epicentro.iss.it/coronavirus/bolle...    80+
#
#                                      vaccino popolazione diagnosi ricoveri  \
# 0                              non vaccinati   3.180.652   35.062      496
# 1                       vaccinati incompleto     964.114    2.294       30
# 2               vaccinati completo <= 6 mesi  11.859.483   28.923      114
# 3                vaccinati completo > 6 mesi   1.322.655    7.705       49
# 4    vaccinati completo + aggiuntiva/booster     108.651      173        1
# ..                                       ...         ...      ...      ...
# 279                     vaccinati incompleto   5.415.352    1.067      151
# 280                       vaccinati completo   4.905.555      568       70
# 281                            non vaccinati     460.790      302      168
# 282                     vaccinati incompleto     281.202       58       27
# 283                       vaccinati completo   3.812.115      487      142
#
#     intensive decessi popolazione_giorno diagnosi_start diagnosi_end  \
# 0          24       8         2021-11-13     2021-10-29   2021-11-28
# 1           0       0         2021-11-13     2021-10-29   2021-11-28
# 2           0       0         2021-11-13     2021-10-29   2021-11-28
# 3           0       1         2021-11-13     2021-10-29   2021-11-28
# 4           0       0         2021-11-13     2021-10-29   2021-11-28
# ..        ...     ...                ...            ...          ...
# 279        17      46         2021-06-26     2021-06-11   2021-07-11
# 280         2      12         2021-06-26     2021-06-11   2021-07-11
# 281        21     147         2021-06-26     2021-06-11   2021-07-11
# 282         0      21         2021-06-26     2021-06-11   2021-07-11
# 283         5      55         2021-06-26     2021-06-11   2021-07-11
#
#     ricoveri_start ricoveri_end intensive_start intensive_end decessi_start  \
# 0       2021-10-15   2021-11-14      2021-10-15    2021-11-14    2021-10-08
# 1       2021-10-15   2021-11-14      2021-10-15    2021-11-14    2021-10-08
# 2       2021-10-15   2021-11-14      2021-10-15    2021-11-14    2021-10-08
# 3       2021-10-15   2021-11-14      2021-10-15    2021-11-14    2021-10-08
# 4       2021-10-15   2021-11-14      2021-10-15    2021-11-14    2021-10-08
# ..             ...          ...             ...           ...           ...
# 279     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 280     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 281     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 282     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 283     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
#
#     decessi_end
# 0    2021-11-07
# 1    2021-11-07
# 2    2021-11-07
# 3    2021-11-07
# 4    2021-11-07
# ..          ...
# 279  2021-06-20
# 280  2021-06-20
# 281  2021-06-20
# 282  2021-06-20
# 283  2021-06-20
#
# [284 rows x 19 columns]

# %%
# integer casting
df["popolazione"] = df.popolazione.str.replace(".", "", regex=False).astype(int)
df["diagnosi"] = df.diagnosi.str.replace(".", "", regex=False).astype(int)
df["ricoveri"] = df.ricoveri.str.replace(".", "", regex=False).astype(int)
df["intensive"] = df.intensive.str.replace(".", "", regex=False).astype(int)
df["decessi"] = df.decessi.str.replace(".", "", regex=False).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   data                284 non-null    datetime64[ns]
#  1   pubblicazione       284 non-null    datetime64[ns]
#  2   url                 284 non-null    object
#  3   fascia              284 non-null    object
#  4   vaccino             284 non-null    object
#  5   popolazione         284 non-null    int64
#  6   diagnosi            284 non-null    int64
#  7   ricoveri            284 non-null    int64
#  8   intensive           284 non-null    int64
#  9   decessi             284 non-null    int64
#  10  popolazione_giorno  284 non-null    datetime64[ns]
#  11  diagnosi_start      284 non-null    datetime64[ns]
#  12  diagnosi_end        284 non-null    datetime64[ns]
#  13  ricoveri_start      284 non-null    datetime64[ns]
#  14  ricoveri_end        284 non-null    datetime64[ns]
#  15  intensive_start     284 non-null    datetime64[ns]
#  16  intensive_end       284 non-null    datetime64[ns]
#  17  decessi_start       284 non-null    datetime64[ns]
#  18  decessi_end         284 non-null    datetime64[ns]
# dtypes: datetime64[ns](11), int64(5), object(3)
# memory usage: 42.3+ KB

# %%
# popolazione totale per data e fascia
popolazione = df.groupby(["data", "fascia"])[["popolazione"]].sum().reset_index()
popolazione
# Out:
#          data fascia  popolazione
# 0  2021-07-14  12-39     17435555
# 1  2021-07-14  40-59     18447460
# 2  2021-07-14  60-79     13572779
# 3  2021-07-14    80+      4554107
# 4  2021-07-21  12-39     17435555
# ..        ...    ...          ...
# 79 2021-11-24    80+      4568359
# 80 2021-12-01  12-39     17435555
# 81 2021-12-01  40-59     18433251
# 82 2021-12-01  60-79     13572779
# 83 2021-12-01    80+      4568359
#
# [84 rows x 3 columns]

# %%
# aggiunta popolazione totale per fascia e data
for data in df.data.unique():
    for fascia in df.fascia.unique():
        _pop = popolazione.loc[(popolazione.data==data)&(popolazione.fascia==fascia), "popolazione"].values[0]
        df.loc[(df.data==data)&(df.fascia==fascia), "totale"] = _pop
df["totale"] = df.totale.astype(int)

# %%
# calcolo percentuale di popolazione per data, fascia e stato vaccinale
df["percentuale_popolazione"] = df.popolazione / df.totale

# %%
# ordinamento per data e fascia
df.sort_values(by=["data", "fascia"], inplace=True)

# %%
# calcolo dei tassi per data, fascia e stato vaccinale
for y in ["diagnosi", "ricoveri", "intensive", "decessi"]:
    df[f"percentuale_{y}"] = df[y] / df.popolazione

# %%
# salvataggio report completo
df.to_csv("../reports_iss_vaccini.csv", index=False)

# %%
# controllo del file salvato
df_check = pd.read_csv(
    "../reports_iss_vaccini.csv",
    parse_dates=[
        "data", "pubblicazione", "popolazione_giorno",
        "diagnosi_start", "diagnosi_end",
        "ricoveri_start", "ricoveri_end",
        "intensive_start", "intensive_end",
        "decessi_start", "decessi_end"
    ]
)
df_check
# Out:
#           data pubblicazione  \
# 0   2021-07-14    2021-07-16
# 1   2021-07-14    2021-07-16
# 2   2021-07-14    2021-07-16
# 3   2021-07-14    2021-07-16
# 4   2021-07-14    2021-07-16
# ..         ...           ...
# 279 2021-12-01    2021-12-03
# 280 2021-12-01    2021-12-03
# 281 2021-12-01    2021-12-03
# 282 2021-12-01    2021-12-03
# 283 2021-12-01    2021-12-03
#
#                                                    url fascia  \
# 0    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 1    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 2    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 3    https://www.epicentro.iss.it/coronavirus/bolle...  40-59
# 4    https://www.epicentro.iss.it/coronavirus/bolle...  40-59
# ..                                                 ...    ...
# 279  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 280  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 281  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 282  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 283  https://www.epicentro.iss.it/coronavirus/bolle...    80+
#
#                                      vaccino  popolazione  diagnosi  ricoveri  \
# 0                              non vaccinati     14011891     13549       513
# 1                       vaccinati incompleto      1815895      1243        11
# 2                         vaccinati completo      1607769       528         4
# 3                              non vaccinati      9340510      5747       779
# 4                       vaccinati incompleto      5502988      1586        51
# ..                                       ...          ...       ...       ...
# 279                            non vaccinati       221018      1927       599
# 280                     vaccinati incompleto        85655       254        62
# 281             vaccinati completo <= 6 mesi       420620       853       228
# 282              vaccinati completo > 6 mesi      2938453      8092      1439
# 283  vaccinati completo + aggiuntiva/booster       902613       693        35
#
#      intensive  decessi  ... intensive_start intensive_end decessi_start  \
# 0           13        7  ...      2021-06-04    2021-07-04    2021-05-21
# 1            0        1  ...      2021-06-04    2021-07-04    2021-05-21
# 2            0        0  ...      2021-06-04    2021-07-04    2021-05-21
# 3           66       45  ...      2021-06-04    2021-07-04    2021-05-21
# 4            3        4  ...      2021-06-04    2021-07-04    2021-05-21
# ..         ...      ...  ...             ...           ...           ...
# 279         39      232  ...      2021-10-15    2021-11-14    2021-10-08
# 280          1       13  ...      2021-10-15    2021-11-14    2021-10-08
# 281         16      100  ...      2021-10-15    2021-11-14    2021-10-08
# 282         65      388  ...      2021-10-15    2021-11-14    2021-10-08
# 283          1       10  ...      2021-10-15    2021-11-14    2021-10-08
#
#     decessi_end    totale percentuale_popolazione percentuale_diagnosi  \
# 0    2021-06-20  17435555                0.803639             0.000967
# 1    2021-06-20  17435555                0.104149             0.000685
# 2    2021-06-20  17435555                0.092212             0.000328
# 3    2021-06-20  18447460                0.506330             0.000615
# 4    2021-06-20  18447460                0.298306             0.000288
# ..          ...       ...                     ...                  ...
# 279  2021-11-07   4568359                0.048380             0.008719
# 280  2021-11-07   4568359                0.018750             0.002965
# 281  2021-11-07   4568359                0.092072             0.002028
# 282  2021-11-07   4568359                0.643218             0.002754
# 283  2021-11-07   4568359                0.197579             0.000768
#
#     percentuale_ricoveri percentuale_intensive  percentuale_decessi
# 0               0.000037          9.277834e-07         4.995757e-07
# 1               0.000006          0.000000e+00         5.506926e-07
# 2               0.000002          0.000000e+00         0.000000e+00
# 3               0.000083          7.065995e-06         4.817724e-06
# 4               0.000009          5.451584e-07         7.268778e-07
# ..                   ...                   ...                  ...
# 279             0.002710          1.764562e-04         1.049688e-03
# 280             0.000724          1.167474e-05         1.517716e-04
# 281             0.000542          3.803909e-05         2.377443e-04
# 282             0.000490          2.212048e-05         1.320423e-04
# 283             0.000039          1.107895e-06         1.107895e-05
#
# [284 rows x 25 columns]

# %%
df_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   data                     284 non-null    datetime64[ns]
#  1   pubblicazione            284 non-null    datetime64[ns]
#  2   url                      284 non-null    object
#  3   fascia                   284 non-null    object
#  4   vaccino                  284 non-null    object
#  5   popolazione              284 non-null    int64
#  6   diagnosi                 284 non-null    int64
#  7   ricoveri                 284 non-null    int64
#  8   intensive                284 non-null    int64
#  9   decessi                  284 non-null    int64
#  10  popolazione_giorno       284 non-null    datetime64[ns]
#  11  diagnosi_start           284 non-null    datetime64[ns]
#  12  diagnosi_end             284 non-null    datetime64[ns]
#  13  ricoveri_start           284 non-null    datetime64[ns]
#  14  ricoveri_end             284 non-null    datetime64[ns]
#  15  intensive_start          284 non-null    datetime64[ns]
#  16  intensive_end            284 non-null    datetime64[ns]
#  17  decessi_start            284 non-null    datetime64[ns]
#  18  decessi_end              284 non-null    datetime64[ns]
#  19  totale                   284 non-null    int64
#  20  percentuale_popolazione  284 non-null    float64
#  21  percentuale_diagnosi     284 non-null    float64
#  22  percentuale_ricoveri     284 non-null    float64
#  23  percentuale_intensive    284 non-null    float64
#  24  percentuale_decessi      284 non-null    float64
# dtypes: datetime64[ns](11), float64(5), int64(6), object(3)
# memory usage: 55.6+ KB
