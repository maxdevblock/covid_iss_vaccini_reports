# %%
import numpy as np
import pandas as pd

# %%
# dataset grezzo
df = pd.read_csv(
    "dataset.csv",
    parse_dates=[
        "data", "pubblicazione", "popolazione_giorno",
        "diagnosi_start", "diagnosi_end",
        "ricoveri_start", "ricoveri_end",
        "intensive_start", "intensive_end",
        "decessi_start", "decessi_end"
    ],
    dtype={
        'popolazione': np.object,
        'diagnosi': np.object,
        'ricoveri': np.object,
        'intensive': np.object,
        'decessi': np.object,
    }
)
df
# Out:
#           data pubblicazione  \
# 0   2021-11-10    2021-11-12
# 1   2021-11-10    2021-11-12
# 2   2021-11-10    2021-11-12
# 3   2021-11-10    2021-11-12
# 4   2021-11-10    2021-11-12
# ..         ...           ...
# 219 2021-07-14    2021-07-16
# 220 2021-07-14    2021-07-16
# 221 2021-07-14    2021-07-16
# 222 2021-07-14    2021-07-16
# 223 2021-07-14    2021-07-16
#
#                                                    url fascia  \
# 0    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 1    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 2    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 3    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 4    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# ..                                                 ...    ...
# 219  https://www.epicentro.iss.it/coronavirus/bolle...  60-79
# 220  https://www.epicentro.iss.it/coronavirus/bolle...  60-79
# 221  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 222  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 223  https://www.epicentro.iss.it/coronavirus/bolle...    80+
#
#                                      vaccino popolazione diagnosi ricoveri  \
# 0                              non vaccinati   3.649.047   18.568      475
# 1                       vaccinati incompleto   1.281.842    1.513       22
# 2               vaccinati completo <= 6 mesi  11.871.919   11.624       78
# 3                vaccinati completo > 6 mesi     620.294    1.535       18
# 4    vaccinati completo + aggiuntiva/booster      12.453       21        1
# ..                                       ...         ...      ...      ...
# 219                     vaccinati incompleto   5.415.352    1.067      151
# 220                       vaccinati completo   4.905.555      568       70
# 221                            non vaccinati     460.790      302      168
# 222                     vaccinati incompleto     281.202       58       27
# 223                       vaccinati completo   3.812.115      487      142
#
#     intensive decessi popolazione_giorno diagnosi_start diagnosi_end  \
# 0          30       3         2021-10-23     2021-10-08   2021-11-07
# 1           1       2         2021-10-23     2021-10-08   2021-11-07
# 2           0       2         2021-10-23     2021-10-08   2021-11-07
# 3           0       0         2021-10-23     2021-10-08   2021-11-07
# 4           0       0         2021-10-23     2021-10-08   2021-11-07
# ..        ...     ...                ...            ...          ...
# 219        17      46         2021-06-26     2021-06-11   2021-07-11
# 220         2      12         2021-06-26     2021-06-11   2021-07-11
# 221        21     147         2021-06-26     2021-06-11   2021-07-11
# 222         0      21         2021-06-26     2021-06-11   2021-07-11
# 223         5      55         2021-06-26     2021-06-11   2021-07-11
#
#     ricoveri_start ricoveri_end intensive_start intensive_end decessi_start  \
# 0       2021-10-01   2021-10-31      2021-10-01    2021-10-31    2021-09-17
# 1       2021-10-01   2021-10-31      2021-10-01    2021-10-31    2021-09-17
# 2       2021-10-01   2021-10-31      2021-10-01    2021-10-31    2021-09-17
# 3       2021-10-01   2021-10-31      2021-10-01    2021-10-31    2021-09-17
# 4       2021-10-01   2021-10-31      2021-10-01    2021-10-31    2021-09-17
# ..             ...          ...             ...           ...           ...
# 219     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 220     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 221     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 222     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 223     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
#
#     decessi_end
# 0    2021-10-17
# 1    2021-10-17
# 2    2021-10-17
# 3    2021-10-17
# 4    2021-10-17
# ..          ...
# 219  2021-06-20
# 220  2021-06-20
# 221  2021-06-20
# 222  2021-06-20
# 223  2021-06-20
#
# [224 rows x 19 columns]

# %%
# integer casting
df["popolazione"] = df.popolazione.str.replace(".", "", regex=False).astype(int)
df["diagnosi"] = df.diagnosi.str.replace(".", "", regex=False).astype(int)
df["ricoveri"] = df.ricoveri.str.replace(".", "", regex=False).astype(int)
df["intensive"] = df.intensive.str.replace(".", "", regex=False).astype(int)
df["decessi"] = df.decessi.str.replace(".", "", regex=False).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   data                224 non-null    datetime64[ns]
#  1   pubblicazione       224 non-null    datetime64[ns]
#  2   url                 224 non-null    object
#  3   fascia              224 non-null    object
#  4   vaccino             224 non-null    object
#  5   popolazione         224 non-null    int64
#  6   diagnosi            224 non-null    int64
#  7   ricoveri            224 non-null    int64
#  8   intensive           224 non-null    int64
#  9   decessi             224 non-null    int64
#  10  popolazione_giorno  224 non-null    datetime64[ns]
#  11  diagnosi_start      224 non-null    datetime64[ns]
#  12  diagnosi_end        224 non-null    datetime64[ns]
#  13  ricoveri_start      224 non-null    datetime64[ns]
#  14  ricoveri_end        224 non-null    datetime64[ns]
#  15  intensive_start     224 non-null    datetime64[ns]
#  16  intensive_end       224 non-null    datetime64[ns]
#  17  decessi_start       224 non-null    datetime64[ns]
#  18  decessi_end         224 non-null    datetime64[ns]
# dtypes: datetime64[ns](11), int64(5), object(3)
# memory usage: 33.4+ KB

# %%
# popolazione totale per data e fascia
popolazione = df.groupby(["data", "fascia"])[["popolazione"]].sum().reset_index()
popolazione
# Out:
#          data fascia  popolazione
# 0  2021-07-14  12-39     17435555
# 1  2021-07-14  40-59     18447460
# 2  2021-07-14  60-79     13572779
# 3  2021-07-14    80+      4554107
# 4  2021-07-21  12-39     17435555
# ..        ...    ...          ...
# 67 2021-11-03    80+      4563500
# 68 2021-11-10  12-39     17435555
# 69 2021-11-10  40-59     18437505
# 70 2021-11-10  60-79     13572779
# 71 2021-11-10    80+      4564103
#
# [72 rows x 3 columns]

# %%
# aggiunta popolazione totale per fascia e data
for data in df.data.unique():
    for fascia in df.fascia.unique():
        _pop = popolazione.loc[(popolazione.data==data)&(popolazione.fascia==fascia), "popolazione"].values[0]
        df.loc[(df.data==data)&(df.fascia==fascia), "totale"] = _pop
df["totale"] = df.totale.astype(int)

# %%
# calcolo percentuale di popolazione per data, fascia e stato vaccinale
df["percentuale_popolazione"] = df.popolazione / df.totale

# %%
# ordinamento per data e fascia
df.sort_values(by=["data", "fascia"], inplace=True)

# %%
# calcolo dei tassi per data, fascia e stato vaccinale
for y in ["diagnosi", "ricoveri", "intensive", "decessi"]:
    df[f"percentuale_{y}"] = df[y] / df.popolazione

# %%
# salvataggio report completo
df.to_csv("../reports_iss_vaccini.csv", index=False)

# %%
# controllo del file salvato
df_check = pd.read_csv(
    "../reports_iss_vaccini.csv",
    parse_dates=[
        "data", "pubblicazione", "popolazione_giorno",
        "diagnosi_start", "diagnosi_end",
        "ricoveri_start", "ricoveri_end",
        "intensive_start", "intensive_end",
        "decessi_start", "decessi_end"
    ]
)
df_check
# Out:
#           data pubblicazione  \
# 0   2021-07-14    2021-07-16
# 1   2021-07-14    2021-07-16
# 2   2021-07-14    2021-07-16
# 3   2021-07-14    2021-07-16
# 4   2021-07-14    2021-07-16
# ..         ...           ...
# 219 2021-11-10    2021-11-12
# 220 2021-11-10    2021-11-12
# 221 2021-11-10    2021-11-12
# 222 2021-11-10    2021-11-12
# 223 2021-11-10    2021-11-12
#
#                                                    url fascia  \
# 0    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 1    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 2    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 3    https://www.epicentro.iss.it/coronavirus/bolle...  40-59
# 4    https://www.epicentro.iss.it/coronavirus/bolle...  40-59
# ..                                                 ...    ...
# 219  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 220  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 221  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 222  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 223  https://www.epicentro.iss.it/coronavirus/bolle...    80+
#
#                                      vaccino  popolazione  diagnosi  ricoveri  \
# 0                              non vaccinati     14011891     13549       513
# 1                       vaccinati incompleto      1815895      1243        11
# 2                         vaccinati completo      1607769       528         4
# 3                              non vaccinati      9340510      5747       779
# 4                       vaccinati incompleto      5502988      1586        51
# ..                                       ...          ...       ...       ...
# 219                            non vaccinati       232553      1223       439
# 220                     vaccinati incompleto        94295       118        35
# 221             vaccinati completo <= 6 mesi      2317784      2621       664
# 222              vaccinati completo > 6 mesi      1776980      2747       487
# 223  vaccinati completo + aggiuntiva/booster       142491       140         6
#
#      intensive  decessi  ... intensive_start intensive_end decessi_start  \
# 0           13        7  ...      2021-06-04    2021-07-04    2021-05-21
# 1            0        1  ...      2021-06-04    2021-07-04    2021-05-21
# 2            0        0  ...      2021-06-04    2021-07-04    2021-05-21
# 3           66       45  ...      2021-06-04    2021-07-04    2021-05-21
# 4            3        4  ...      2021-06-04    2021-07-04    2021-05-21
# ..         ...      ...  ...             ...           ...           ...
# 219         26      162  ...      2021-10-01    2021-10-31    2021-09-17
# 220          0       13  ...      2021-10-01    2021-10-31    2021-09-17
# 221         40      214  ...      2021-10-01    2021-10-31    2021-09-17
# 222         21       76  ...      2021-10-01    2021-10-31    2021-09-17
# 223          1        0  ...      2021-10-01    2021-10-31    2021-09-17
#
#     decessi_end    totale percentuale_popolazione percentuale_diagnosi  \
# 0    2021-06-20  17435555                0.803639             0.000967
# 1    2021-06-20  17435555                0.104149             0.000685
# 2    2021-06-20  17435555                0.092212             0.000328
# 3    2021-06-20  18447460                0.506330             0.000615
# 4    2021-06-20  18447460                0.298306             0.000288
# ..          ...       ...                     ...                  ...
# 219  2021-10-17   4564103                0.050953             0.005259
# 220  2021-10-17   4564103                0.020660             0.001251
# 221  2021-10-17   4564103                0.507829             0.001131
# 222  2021-10-17   4564103                0.389338             0.001546
# 223  2021-10-17   4564103                0.031220             0.000983
#
#     percentuale_ricoveri percentuale_intensive  percentuale_decessi
# 0               0.000037          9.277834e-07         4.995757e-07
# 1               0.000006          0.000000e+00         5.506926e-07
# 2               0.000002          0.000000e+00         0.000000e+00
# 3               0.000083          7.065995e-06         4.817724e-06
# 4               0.000009          5.451584e-07         7.268778e-07
# ..                   ...                   ...                  ...
# 219             0.001888          1.118025e-04         6.966154e-04
# 220             0.000371          0.000000e+00         1.378652e-04
# 221             0.000286          1.725786e-05         9.232957e-05
# 222             0.000274          1.181780e-05         4.276919e-05
# 223             0.000042          7.017987e-06         0.000000e+00
#
# [224 rows x 25 columns]

# %%
df_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   data                     224 non-null    datetime64[ns]
#  1   pubblicazione            224 non-null    datetime64[ns]
#  2   url                      224 non-null    object
#  3   fascia                   224 non-null    object
#  4   vaccino                  224 non-null    object
#  5   popolazione              224 non-null    int64
#  6   diagnosi                 224 non-null    int64
#  7   ricoveri                 224 non-null    int64
#  8   intensive                224 non-null    int64
#  9   decessi                  224 non-null    int64
#  10  popolazione_giorno       224 non-null    datetime64[ns]
#  11  diagnosi_start           224 non-null    datetime64[ns]
#  12  diagnosi_end             224 non-null    datetime64[ns]
#  13  ricoveri_start           224 non-null    datetime64[ns]
#  14  ricoveri_end             224 non-null    datetime64[ns]
#  15  intensive_start          224 non-null    datetime64[ns]
#  16  intensive_end            224 non-null    datetime64[ns]
#  17  decessi_start            224 non-null    datetime64[ns]
#  18  decessi_end              224 non-null    datetime64[ns]
#  19  totale                   224 non-null    int64
#  20  percentuale_popolazione  224 non-null    float64
#  21  percentuale_diagnosi     224 non-null    float64
#  22  percentuale_ricoveri     224 non-null    float64
#  23  percentuale_intensive    224 non-null    float64
#  24  percentuale_decessi      224 non-null    float64
# dtypes: datetime64[ns](11), float64(5), int64(6), object(3)
# memory usage: 43.9+ KB
