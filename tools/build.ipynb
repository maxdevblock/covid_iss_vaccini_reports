# %%
import numpy as np
import pandas as pd

# %%
# dataset grezzo
df = pd.read_csv(
    "dataset.csv",
    parse_dates=[
        "data", "pubblicazione", "popolazione_giorno",
        "diagnosi_start", "diagnosi_end",
        "ricoveri_start", "ricoveri_end",
        "intensive_start", "intensive_end",
        "decessi_start", "decessi_end"
    ],
    dtype={
        'popolazione': np.object,
        'diagnosi': np.object,
        'ricoveri': np.object,
        'intensive': np.object,
        'decessi': np.object,
    }
)
df
# Out:
#           data pubblicazione  \
# 0   2021-11-24    2021-11-26
# 1   2021-11-24    2021-11-26
# 2   2021-11-24    2021-11-26
# 3   2021-11-24    2021-11-26
# 4   2021-11-24    2021-11-26
# ..         ...           ...
# 259 2021-07-14    2021-07-16
# 260 2021-07-14    2021-07-16
# 261 2021-07-14    2021-07-16
# 262 2021-07-14    2021-07-16
# 263 2021-07-14    2021-07-16
#
#                                                    url fascia  \
# 0    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 1    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 2    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 3    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 4    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# ..                                                 ...    ...
# 259  https://www.epicentro.iss.it/coronavirus/bolle...  60-79
# 260  https://www.epicentro.iss.it/coronavirus/bolle...  60-79
# 261  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 262  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 263  https://www.epicentro.iss.it/coronavirus/bolle...    80+
#
#                                      vaccino popolazione diagnosi ricoveri  \
# 0                              non vaccinati   3.271.713   28.535      505
# 1                       vaccinati incompleto   1.087.094    1.730       25
# 2               vaccinati completo <= 6 mesi  12.382.786   23.907      121
# 3                vaccinati completo > 6 mesi     638.196    2.910       33
# 4    vaccinati completo + aggiuntiva/booster      55.766       90        1
# ..                                       ...         ...      ...      ...
# 259                     vaccinati incompleto   5.415.352    1.067      151
# 260                       vaccinati completo   4.905.555      568       70
# 261                            non vaccinati     460.790      302      168
# 262                     vaccinati incompleto     281.202       58       27
# 263                       vaccinati completo   3.812.115      487      142
#
#     intensive decessi popolazione_giorno diagnosi_start diagnosi_end  \
# 0          23       7         2021-11-06     2021-10-22   2021-11-21
# 1           0       0         2021-11-06     2021-10-22   2021-11-21
# 2           0       1         2021-11-06     2021-10-22   2021-11-21
# 3           0       0         2021-11-06     2021-10-22   2021-11-21
# 4           0       0         2021-11-06     2021-10-22   2021-11-21
# ..        ...     ...                ...            ...          ...
# 259        17      46         2021-06-26     2021-06-11   2021-07-11
# 260         2      12         2021-06-26     2021-06-11   2021-07-11
# 261        21     147         2021-06-26     2021-06-11   2021-07-11
# 262         0      21         2021-06-26     2021-06-11   2021-07-11
# 263         5      55         2021-06-26     2021-06-11   2021-07-11
#
#     ricoveri_start ricoveri_end intensive_start intensive_end decessi_start  \
# 0       2021-10-15   2021-11-14      2021-10-15    2021-11-14    2021-10-01
# 1       2021-10-15   2021-11-14      2021-10-15    2021-11-14    2021-10-01
# 2       2021-10-15   2021-11-14      2021-10-15    2021-11-14    2021-10-01
# 3       2021-10-15   2021-11-14      2021-10-15    2021-11-14    2021-10-01
# 4       2021-10-15   2021-11-14      2021-10-15    2021-11-14    2021-10-01
# ..             ...          ...             ...           ...           ...
# 259     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 260     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 261     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 262     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 263     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
#
#     decessi_end
# 0    2021-10-31
# 1    2021-10-31
# 2    2021-10-31
# 3    2021-10-31
# 4    2021-10-31
# ..          ...
# 259  2021-06-20
# 260  2021-06-20
# 261  2021-06-20
# 262  2021-06-20
# 263  2021-06-20
#
# [264 rows x 19 columns]

# %%
# integer casting
df["popolazione"] = df.popolazione.str.replace(".", "", regex=False).astype(int)
df["diagnosi"] = df.diagnosi.str.replace(".", "", regex=False).astype(int)
df["ricoveri"] = df.ricoveri.str.replace(".", "", regex=False).astype(int)
df["intensive"] = df.intensive.str.replace(".", "", regex=False).astype(int)
df["decessi"] = df.decessi.str.replace(".", "", regex=False).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   data                264 non-null    datetime64[ns]
#  1   pubblicazione       264 non-null    datetime64[ns]
#  2   url                 264 non-null    object
#  3   fascia              264 non-null    object
#  4   vaccino             264 non-null    object
#  5   popolazione         264 non-null    int64
#  6   diagnosi            264 non-null    int64
#  7   ricoveri            264 non-null    int64
#  8   intensive           264 non-null    int64
#  9   decessi             264 non-null    int64
#  10  popolazione_giorno  264 non-null    datetime64[ns]
#  11  diagnosi_start      264 non-null    datetime64[ns]
#  12  diagnosi_end        264 non-null    datetime64[ns]
#  13  ricoveri_start      264 non-null    datetime64[ns]
#  14  ricoveri_end        264 non-null    datetime64[ns]
#  15  intensive_start     264 non-null    datetime64[ns]
#  16  intensive_end       264 non-null    datetime64[ns]
#  17  decessi_start       264 non-null    datetime64[ns]
#  18  decessi_end         264 non-null    datetime64[ns]
# dtypes: datetime64[ns](11), int64(5), object(3)
# memory usage: 39.3+ KB

# %%
# popolazione totale per data e fascia
popolazione = df.groupby(["data", "fascia"])[["popolazione"]].sum().reset_index()
popolazione
# Out:
#          data fascia  popolazione
# 0  2021-07-14  12-39     17435555
# 1  2021-07-14  40-59     18447460
# 2  2021-07-14  60-79     13572779
# 3  2021-07-14    80+      4554107
# 4  2021-07-21  12-39     17435555
# ..        ...    ...          ...
# 75 2021-11-17    80+      4564103
# 76 2021-11-24  12-39     17435555
# 77 2021-11-24  40-59     18433251
# 78 2021-11-24  60-79     13572779
# 79 2021-11-24    80+      4568359
#
# [80 rows x 3 columns]

# %%
# aggiunta popolazione totale per fascia e data
for data in df.data.unique():
    for fascia in df.fascia.unique():
        _pop = popolazione.loc[(popolazione.data==data)&(popolazione.fascia==fascia), "popolazione"].values[0]
        df.loc[(df.data==data)&(df.fascia==fascia), "totale"] = _pop
df["totale"] = df.totale.astype(int)

# %%
# calcolo percentuale di popolazione per data, fascia e stato vaccinale
df["percentuale_popolazione"] = df.popolazione / df.totale

# %%
# ordinamento per data e fascia
df.sort_values(by=["data", "fascia"], inplace=True)

# %%
# calcolo dei tassi per data, fascia e stato vaccinale
for y in ["diagnosi", "ricoveri", "intensive", "decessi"]:
    df[f"percentuale_{y}"] = df[y] / df.popolazione

# %%
# salvataggio report completo
df.to_csv("../reports_iss_vaccini.csv", index=False)

# %%
# controllo del file salvato
df_check = pd.read_csv(
    "../reports_iss_vaccini.csv",
    parse_dates=[
        "data", "pubblicazione", "popolazione_giorno",
        "diagnosi_start", "diagnosi_end",
        "ricoveri_start", "ricoveri_end",
        "intensive_start", "intensive_end",
        "decessi_start", "decessi_end"
    ]
)
df_check
# Out:
#           data pubblicazione  \
# 0   2021-07-14    2021-07-16
# 1   2021-07-14    2021-07-16
# 2   2021-07-14    2021-07-16
# 3   2021-07-14    2021-07-16
# 4   2021-07-14    2021-07-16
# ..         ...           ...
# 259 2021-11-24    2021-11-26
# 260 2021-11-24    2021-11-26
# 261 2021-11-24    2021-11-26
# 262 2021-11-24    2021-11-26
# 263 2021-11-24    2021-11-26
#
#                                                    url fascia  \
# 0    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 1    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 2    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 3    https://www.epicentro.iss.it/coronavirus/bolle...  40-59
# 4    https://www.epicentro.iss.it/coronavirus/bolle...  40-59
# ..                                                 ...    ...
# 259  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 260  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 261  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 262  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 263  https://www.epicentro.iss.it/coronavirus/bolle...    80+
#
#                                      vaccino  popolazione  diagnosi  ricoveri  \
# 0                              non vaccinati     14011891     13549       513
# 1                       vaccinati incompleto      1815895      1243        11
# 2                         vaccinati completo      1607769       528         4
# 3                              non vaccinati      9340510      5747       779
# 4                       vaccinati incompleto      5502988      1586        51
# ..                                       ...          ...       ...       ...
# 259                            non vaccinati       228056      1761       612
# 260                     vaccinati incompleto        88040       169        52
# 261             vaccinati completo <= 6 mesi      1584000      2754       710
# 262              vaccinati completo > 6 mesi      2078888      5093       899
# 263  vaccinati completo + aggiuntiva/booster       589375       401        32
#
#      intensive  decessi  ... intensive_start intensive_end decessi_start  \
# 0           13        7  ...      2021-06-04    2021-07-04    2021-05-21
# 1            0        1  ...      2021-06-04    2021-07-04    2021-05-21
# 2            0        0  ...      2021-06-04    2021-07-04    2021-05-21
# 3           66       45  ...      2021-06-04    2021-07-04    2021-05-21
# 4            3        4  ...      2021-06-04    2021-07-04    2021-05-21
# ..         ...      ...  ...             ...           ...           ...
# 259         35      200  ...      2021-10-15    2021-11-14    2021-10-01
# 260          1       10  ...      2021-10-15    2021-11-14    2021-10-01
# 261         39      236  ...      2021-10-15    2021-11-14    2021-10-01
# 262         35      172  ...      2021-10-15    2021-11-14    2021-10-01
# 263          1        5  ...      2021-10-15    2021-11-14    2021-10-01
#
#     decessi_end    totale percentuale_popolazione percentuale_diagnosi  \
# 0    2021-06-20  17435555                0.803639             0.000967
# 1    2021-06-20  17435555                0.104149             0.000685
# 2    2021-06-20  17435555                0.092212             0.000328
# 3    2021-06-20  18447460                0.506330             0.000615
# 4    2021-06-20  18447460                0.298306             0.000288
# ..          ...       ...                     ...                  ...
# 259  2021-10-31   4568359                0.049921             0.007722
# 260  2021-10-31   4568359                0.019272             0.001920
# 261  2021-10-31   4568359                0.346733             0.001739
# 262  2021-10-31   4568359                0.455062             0.002450
# 263  2021-10-31   4568359                0.129012             0.000680
#
#     percentuale_ricoveri percentuale_intensive  percentuale_decessi
# 0               0.000037          9.277834e-07         4.995757e-07
# 1               0.000006          0.000000e+00         5.506926e-07
# 2               0.000002          0.000000e+00         0.000000e+00
# 3               0.000083          7.065995e-06         4.817724e-06
# 4               0.000009          5.451584e-07         7.268778e-07
# ..                   ...                   ...                  ...
# 259             0.002684          1.534711e-04         8.769776e-04
# 260             0.000591          1.135847e-05         1.135847e-04
# 261             0.000448          2.462121e-05         1.489899e-04
# 262             0.000432          1.683592e-05         8.273654e-05
# 263             0.000054          1.696713e-06         8.483563e-06
#
# [264 rows x 25 columns]

# %%
df_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   data                     264 non-null    datetime64[ns]
#  1   pubblicazione            264 non-null    datetime64[ns]
#  2   url                      264 non-null    object
#  3   fascia                   264 non-null    object
#  4   vaccino                  264 non-null    object
#  5   popolazione              264 non-null    int64
#  6   diagnosi                 264 non-null    int64
#  7   ricoveri                 264 non-null    int64
#  8   intensive                264 non-null    int64
#  9   decessi                  264 non-null    int64
#  10  popolazione_giorno       264 non-null    datetime64[ns]
#  11  diagnosi_start           264 non-null    datetime64[ns]
#  12  diagnosi_end             264 non-null    datetime64[ns]
#  13  ricoveri_start           264 non-null    datetime64[ns]
#  14  ricoveri_end             264 non-null    datetime64[ns]
#  15  intensive_start          264 non-null    datetime64[ns]
#  16  intensive_end            264 non-null    datetime64[ns]
#  17  decessi_start            264 non-null    datetime64[ns]
#  18  decessi_end              264 non-null    datetime64[ns]
#  19  totale                   264 non-null    int64
#  20  percentuale_popolazione  264 non-null    float64
#  21  percentuale_diagnosi     264 non-null    float64
#  22  percentuale_ricoveri     264 non-null    float64
#  23  percentuale_intensive    264 non-null    float64
#  24  percentuale_decessi      264 non-null    float64
# dtypes: datetime64[ns](11), float64(5), int64(6), object(3)
# memory usage: 51.7+ KB
