# %%
import numpy as np
import pandas as pd

# %%
# dataset grezzo
df = pd.read_csv(
    "dataset.csv",
    parse_dates=[
        "data", "pubblicazione", "popolazione_giorno",
        "diagnosi_start", "diagnosi_end",
        "ricoveri_start", "ricoveri_end",
        "intensive_start", "intensive_end",
        "decessi_start", "decessi_end"
    ],
    dtype={
        'popolazione': np.object,
        'diagnosi': np.object,
        'ricoveri': np.object,
        'intensive': np.object,
        'decessi': np.object,
    }
)
df
# Out:
#           data pubblicazione  \
# 0   2021-12-07    2021-12-10
# 1   2021-12-07    2021-12-10
# 2   2021-12-07    2021-12-10
# 3   2021-12-07    2021-12-10
# 4   2021-12-07    2021-12-10
# ..         ...           ...
# 299 2021-07-14    2021-07-16
# 300 2021-07-14    2021-07-16
# 301 2021-07-14    2021-07-16
# 302 2021-07-14    2021-07-16
# 303 2021-07-14    2021-07-16
#
#                                                    url fascia  \
# 0    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 1    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 2    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 3    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 4    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# ..                                                 ...    ...
# 299  https://www.epicentro.iss.it/coronavirus/bolle...  60-79
# 300  https://www.epicentro.iss.it/coronavirus/bolle...  60-79
# 301  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 302  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 303  https://www.epicentro.iss.it/coronavirus/bolle...    80+
#
#                                      vaccino popolazione diagnosi ricoveri  \
# 0                              non vaccinati   3.117.673   43.398      540
# 1                       vaccinati incompleto     846.923    2.513       29
# 2               vaccinati completo <= 5 mesi  11.837.411   37.499      131
# 3                vaccinati completo > 5 mesi   1.480.136   10.366       66
# 4    vaccinati completo + aggiuntiva/booster     153.412      296        1
# ..                                       ...         ...      ...      ...
# 299                     vaccinati incompleto   5.415.352    1.067      151
# 300                       vaccinati completo   4.905.555      568       70
# 301                            non vaccinati     460.790      302      168
# 302                     vaccinati incompleto     281.202       58       27
# 303                       vaccinati completo   3.812.115      487      142
#
#     intensive decessi popolazione_giorno diagnosi_start diagnosi_end  \
# 0          24       7         2021-11-20     2021-11-05   2021-12-05
# 1           0       0         2021-11-20     2021-11-05   2021-12-05
# 2           1       0         2021-11-20     2021-11-05   2021-12-05
# 3           2       1         2021-11-20     2021-11-05   2021-12-05
# 4           0       0         2021-11-20     2021-11-05   2021-12-05
# ..        ...     ...                ...            ...          ...
# 299        17      46         2021-06-26     2021-06-11   2021-07-11
# 300         2      12         2021-06-26     2021-06-11   2021-07-11
# 301        21     147         2021-06-26     2021-06-11   2021-07-11
# 302         0      21         2021-06-26     2021-06-11   2021-07-11
# 303         5      55         2021-06-26     2021-06-11   2021-07-11
#
#     ricoveri_start ricoveri_end intensive_start intensive_end decessi_start  \
# 0       2021-10-22   2021-11-21      2021-10-22    2021-11-21    2021-10-15
# 1       2021-10-22   2021-11-21      2021-10-22    2021-11-21    2021-10-15
# 2       2021-10-22   2021-11-21      2021-10-22    2021-11-21    2021-10-15
# 3       2021-10-22   2021-11-21      2021-10-22    2021-11-21    2021-10-15
# 4       2021-10-22   2021-11-21      2021-10-22    2021-11-21    2021-10-15
# ..             ...          ...             ...           ...           ...
# 299     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 300     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 301     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 302     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 303     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
#
#     decessi_end
# 0    2021-11-14
# 1    2021-11-14
# 2    2021-11-14
# 3    2021-11-14
# 4    2021-11-14
# ..          ...
# 299  2021-06-20
# 300  2021-06-20
# 301  2021-06-20
# 302  2021-06-20
# 303  2021-06-20
#
# [304 rows x 19 columns]

# %%
# integer casting
df["popolazione"] = df.popolazione.str.replace(".", "", regex=False).astype(int)
df["diagnosi"] = df.diagnosi.str.replace(".", "", regex=False).astype(int)
df["ricoveri"] = df.ricoveri.str.replace(".", "", regex=False).astype(int)
df["intensive"] = df.intensive.str.replace(".", "", regex=False).astype(int)
df["decessi"] = df.decessi.str.replace(".", "", regex=False).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   data                304 non-null    datetime64[ns]
#  1   pubblicazione       304 non-null    datetime64[ns]
#  2   url                 304 non-null    object
#  3   fascia              304 non-null    object
#  4   vaccino             304 non-null    object
#  5   popolazione         304 non-null    int64
#  6   diagnosi            304 non-null    int64
#  7   ricoveri            304 non-null    int64
#  8   intensive           304 non-null    int64
#  9   decessi             304 non-null    int64
#  10  popolazione_giorno  304 non-null    datetime64[ns]
#  11  diagnosi_start      304 non-null    datetime64[ns]
#  12  diagnosi_end        304 non-null    datetime64[ns]
#  13  ricoveri_start      304 non-null    datetime64[ns]
#  14  ricoveri_end        304 non-null    datetime64[ns]
#  15  intensive_start     304 non-null    datetime64[ns]
#  16  intensive_end       304 non-null    datetime64[ns]
#  17  decessi_start       304 non-null    datetime64[ns]
#  18  decessi_end         304 non-null    datetime64[ns]
# dtypes: datetime64[ns](11), int64(5), object(3)
# memory usage: 45.2+ KB

# %%
# popolazione totale per data e fascia
popolazione = df.groupby(["data", "fascia"])[["popolazione"]].sum().reset_index()
popolazione
# Out:
#          data fascia  popolazione
# 0  2021-07-14  12-39     17435555
# 1  2021-07-14  40-59     18447460
# 2  2021-07-14  60-79     13572779
# 3  2021-07-14    80+      4554107
# 4  2021-07-21  12-39     17435555
# ..        ...    ...          ...
# 83 2021-12-01    80+      4568359
# 84 2021-12-07  12-39     17435555
# 85 2021-12-07  40-59     18433251
# 86 2021-12-07  60-79     13572779
# 87 2021-12-07    80+      4568359
#
# [88 rows x 3 columns]

# %%
# aggiunta popolazione totale per fascia e data
for data in df.data.unique():
    for fascia in df.fascia.unique():
        _pop = popolazione.loc[(popolazione.data==data)&(popolazione.fascia==fascia), "popolazione"].values[0]
        df.loc[(df.data==data)&(df.fascia==fascia), "totale"] = _pop
df["totale"] = df.totale.astype(int)

# %%
# calcolo percentuale di popolazione per data, fascia e stato vaccinale
df["percentuale_popolazione"] = df.popolazione / df.totale

# %%
# ordinamento per data e fascia
df.sort_values(by=["data", "fascia"], inplace=True)

# %%
# calcolo dei tassi per data, fascia e stato vaccinale
for y in ["diagnosi", "ricoveri", "intensive", "decessi"]:
    df[f"percentuale_{y}"] = df[y] / df.popolazione

# %%
# salvataggio report completo
df.to_csv("../reports_iss_vaccini.csv", index=False)

# %%
# controllo del file salvato
df_check = pd.read_csv(
    "../reports_iss_vaccini.csv",
    parse_dates=[
        "data", "pubblicazione", "popolazione_giorno",
        "diagnosi_start", "diagnosi_end",
        "ricoveri_start", "ricoveri_end",
        "intensive_start", "intensive_end",
        "decessi_start", "decessi_end"
    ]
)
df_check
# Out:
#           data pubblicazione  \
# 0   2021-07-14    2021-07-16
# 1   2021-07-14    2021-07-16
# 2   2021-07-14    2021-07-16
# 3   2021-07-14    2021-07-16
# 4   2021-07-14    2021-07-16
# ..         ...           ...
# 299 2021-12-07    2021-12-10
# 300 2021-12-07    2021-12-10
# 301 2021-12-07    2021-12-10
# 302 2021-12-07    2021-12-10
# 303 2021-12-07    2021-12-10
#
#                                                    url fascia  \
# 0    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 1    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 2    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 3    https://www.epicentro.iss.it/coronavirus/bolle...  40-59
# 4    https://www.epicentro.iss.it/coronavirus/bolle...  40-59
# ..                                                 ...    ...
# 299  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 300  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 301  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 302  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 303  https://www.epicentro.iss.it/coronavirus/bolle...    80+
#
#                                      vaccino  popolazione  diagnosi  ricoveri  \
# 0                              non vaccinati     14011891     13549       513
# 1                       vaccinati incompleto      1815895      1243        11
# 2                         vaccinati completo      1607769       528         4
# 3                              non vaccinati      9340510      5747       779
# 4                       vaccinati incompleto      5502988      1586        51
# ..                                       ...          ...       ...       ...
# 299                            non vaccinati       218428      2305       728
# 300                     vaccinati incompleto        83911       272        70
# 301             vaccinati completo <= 5 mesi       376383       861       213
# 302              vaccinati completo > 5 mesi      2698556      8862      1697
# 303  vaccinati completo + aggiuntiva/booster      1191081      1014        58
#
#      intensive  decessi  ... intensive_start intensive_end decessi_start  \
# 0           13        7  ...      2021-06-04    2021-07-04    2021-05-21
# 1            0        1  ...      2021-06-04    2021-07-04    2021-05-21
# 2            0        0  ...      2021-06-04    2021-07-04    2021-05-21
# 3           66       45  ...      2021-06-04    2021-07-04    2021-05-21
# 4            3        4  ...      2021-06-04    2021-07-04    2021-05-21
# ..         ...      ...  ...             ...           ...           ...
# 299         44      291  ...      2021-10-22    2021-11-21    2021-10-15
# 300          2       16  ...      2021-10-22    2021-11-21    2021-10-15
# 301         17       85  ...      2021-10-22    2021-11-21    2021-10-15
# 302         68      476  ...      2021-10-22    2021-11-21    2021-10-15
# 303          2       13  ...      2021-10-22    2021-11-21    2021-10-15
#
#     decessi_end    totale percentuale_popolazione percentuale_diagnosi  \
# 0    2021-06-20  17435555                0.803639             0.000967
# 1    2021-06-20  17435555                0.104149             0.000685
# 2    2021-06-20  17435555                0.092212             0.000328
# 3    2021-06-20  18447460                0.506330             0.000615
# 4    2021-06-20  18447460                0.298306             0.000288
# ..          ...       ...                     ...                  ...
# 299  2021-11-14   4568359                0.047813             0.010553
# 300  2021-11-14   4568359                0.018368             0.003242
# 301  2021-11-14   4568359                0.082389             0.002288
# 302  2021-11-14   4568359                0.590706             0.003284
# 303  2021-11-14   4568359                0.260724             0.000851
#
#     percentuale_ricoveri percentuale_intensive  percentuale_decessi
# 0               0.000037          9.277834e-07         4.995757e-07
# 1               0.000006          0.000000e+00         5.506926e-07
# 2               0.000002          0.000000e+00         0.000000e+00
# 3               0.000083          7.065995e-06         4.817724e-06
# 4               0.000009          5.451584e-07         7.268778e-07
# ..                   ...                   ...                  ...
# 299             0.003333          2.014394e-04         1.332247e-03
# 300             0.000834          2.383478e-05         1.906782e-04
# 301             0.000566          4.516676e-05         2.258338e-04
# 302             0.000629          2.519866e-05         1.763906e-04
# 303             0.000049          1.679147e-06         1.091446e-05
#
# [304 rows x 25 columns]

# %%
df_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   data                     304 non-null    datetime64[ns]
#  1   pubblicazione            304 non-null    datetime64[ns]
#  2   url                      304 non-null    object
#  3   fascia                   304 non-null    object
#  4   vaccino                  304 non-null    object
#  5   popolazione              304 non-null    int64
#  6   diagnosi                 304 non-null    int64
#  7   ricoveri                 304 non-null    int64
#  8   intensive                304 non-null    int64
#  9   decessi                  304 non-null    int64
#  10  popolazione_giorno       304 non-null    datetime64[ns]
#  11  diagnosi_start           304 non-null    datetime64[ns]
#  12  diagnosi_end             304 non-null    datetime64[ns]
#  13  ricoveri_start           304 non-null    datetime64[ns]
#  14  ricoveri_end             304 non-null    datetime64[ns]
#  15  intensive_start          304 non-null    datetime64[ns]
#  16  intensive_end            304 non-null    datetime64[ns]
#  17  decessi_start            304 non-null    datetime64[ns]
#  18  decessi_end              304 non-null    datetime64[ns]
#  19  totale                   304 non-null    int64
#  20  percentuale_popolazione  304 non-null    float64
#  21  percentuale_diagnosi     304 non-null    float64
#  22  percentuale_ricoveri     304 non-null    float64
#  23  percentuale_intensive    304 non-null    float64
#  24  percentuale_decessi      304 non-null    float64
# dtypes: datetime64[ns](11), float64(5), int64(6), object(3)
# memory usage: 59.5+ KB
