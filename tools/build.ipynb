# %%
import numpy as np
import pandas as pd

# %%
# dataset grezzo
df = pd.read_csv(
    "dataset.csv",
    parse_dates=[
        "data", "pubblicazione", "popolazione_giorno",
        "diagnosi_start", "diagnosi_end",
        "ricoveri_start", "ricoveri_end",
        "intensive_start", "intensive_end",
        "decessi_start", "decessi_end"
    ],
    dtype={
        'popolazione': np.object,
        'diagnosi': np.object,
        'ricoveri': np.object,
        'intensive': np.object,
        'decessi': np.object,
    }
)
df
# Out:
#           data pubblicazione  \
# 0   2021-12-15    2021-12-17
# 1   2021-12-15    2021-12-17
# 2   2021-12-15    2021-12-17
# 3   2021-12-15    2021-12-17
# 4   2021-12-15    2021-12-17
# ..         ...           ...
# 319 2021-07-14    2021-07-16
# 320 2021-07-14    2021-07-16
# 321 2021-07-14    2021-07-16
# 322 2021-07-14    2021-07-16
# 323 2021-07-14    2021-07-16
#
#                                                    url fascia  \
# 0    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 1    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 2    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 3    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 4    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# ..                                                 ...    ...
# 319  https://www.epicentro.iss.it/coronavirus/bolle...  60-79
# 320  https://www.epicentro.iss.it/coronavirus/bolle...  60-79
# 321  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 322  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 323  https://www.epicentro.iss.it/coronavirus/bolle...    80+
#
#                                      vaccino popolazione diagnosi ricoveri  \
# 0                              non vaccinati   3.046.339   52.862      586
# 1                       vaccinati incompleto     760.046    2.871       32
# 2               vaccinati completo <= 5 mesi  11.830.250   47.295      149
# 3                vaccinati completo > 5 mesi   1.578.817   13.430       77
# 4    vaccinati completo + aggiuntiva/booster     220.103      527        3
# ..                                       ...         ...      ...      ...
# 319                     vaccinati incompleto   5.415.352    1.067      151
# 320                       vaccinati completo   4.905.555      568       70
# 321                            non vaccinati     460.790      302      168
# 322                     vaccinati incompleto     281.202       58       27
# 323                       vaccinati completo   3.812.115      487      142
#
#     intensive decessi popolazione_giorno diagnosi_start diagnosi_end  \
# 0          27       6         2021-11-27     2021-11-12   2021-12-12
# 1           0       0         2021-11-27     2021-11-12   2021-12-12
# 2           2       0         2021-11-27     2021-11-12   2021-12-12
# 3           2       1         2021-11-27     2021-11-12   2021-12-12
# 4           0       0         2021-11-27     2021-11-12   2021-12-12
# ..        ...     ...                ...            ...          ...
# 319        17      46         2021-06-26     2021-06-11   2021-07-11
# 320         2      12         2021-06-26     2021-06-11   2021-07-11
# 321        21     147         2021-06-26     2021-06-11   2021-07-11
# 322         0      21         2021-06-26     2021-06-11   2021-07-11
# 323         5      55         2021-06-26     2021-06-11   2021-07-11
#
#     ricoveri_start ricoveri_end intensive_start intensive_end decessi_start  \
# 0       2021-10-29   2021-11-28      2021-10-29    2021-11-28    2021-10-22
# 1       2021-10-29   2021-11-28      2021-10-29    2021-11-28    2021-10-22
# 2       2021-10-29   2021-11-28      2021-10-29    2021-11-28    2021-10-22
# 3       2021-10-29   2021-11-28      2021-10-29    2021-11-28    2021-10-22
# 4       2021-10-29   2021-11-28      2021-10-29    2021-11-28    2021-10-22
# ..             ...          ...             ...           ...           ...
# 319     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 320     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 321     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 322     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
# 323     2021-06-04   2021-07-04      2021-06-04    2021-07-04    2021-05-21
#
#     decessi_end
# 0    2021-11-21
# 1    2021-11-21
# 2    2021-11-21
# 3    2021-11-21
# 4    2021-11-21
# ..          ...
# 319  2021-06-20
# 320  2021-06-20
# 321  2021-06-20
# 322  2021-06-20
# 323  2021-06-20
#
# [324 rows x 19 columns]

# %%
# integer casting
df["popolazione"] = df.popolazione.str.replace(".", "", regex=False).astype(int)
df["diagnosi"] = df.diagnosi.str.replace(".", "", regex=False).astype(int)
df["ricoveri"] = df.ricoveri.str.replace(".", "", regex=False).astype(int)
df["intensive"] = df.intensive.str.replace(".", "", regex=False).astype(int)
df["decessi"] = df.decessi.str.replace(".", "", regex=False).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   data                324 non-null    datetime64[ns]
#  1   pubblicazione       324 non-null    datetime64[ns]
#  2   url                 324 non-null    object
#  3   fascia              324 non-null    object
#  4   vaccino             324 non-null    object
#  5   popolazione         324 non-null    int64
#  6   diagnosi            324 non-null    int64
#  7   ricoveri            324 non-null    int64
#  8   intensive           324 non-null    int64
#  9   decessi             324 non-null    int64
#  10  popolazione_giorno  324 non-null    datetime64[ns]
#  11  diagnosi_start      324 non-null    datetime64[ns]
#  12  diagnosi_end        324 non-null    datetime64[ns]
#  13  ricoveri_start      324 non-null    datetime64[ns]
#  14  ricoveri_end        324 non-null    datetime64[ns]
#  15  intensive_start     324 non-null    datetime64[ns]
#  16  intensive_end       324 non-null    datetime64[ns]
#  17  decessi_start       324 non-null    datetime64[ns]
#  18  decessi_end         324 non-null    datetime64[ns]
# dtypes: datetime64[ns](11), int64(5), object(3)
# memory usage: 48.2+ KB

# %%
# popolazione totale per data e fascia
popolazione = df.groupby(["data", "fascia"])[["popolazione"]].sum().reset_index()
popolazione
# Out:
#          data fascia  popolazione
# 0  2021-07-14  12-39     17435555
# 1  2021-07-14  40-59     18447460
# 2  2021-07-14  60-79     13572779
# 3  2021-07-14    80+      4554107
# 4  2021-07-21  12-39     17435555
# ..        ...    ...          ...
# 87 2021-12-07    80+      4568359
# 88 2021-12-15  12-39     17435555
# 89 2021-12-15  40-59     18432076
# 90 2021-12-15  60-79     13572604
# 91 2021-12-15    80+      4569709
#
# [92 rows x 3 columns]

# %%
# aggiunta popolazione totale per fascia e data
for data in df.data.unique():
    for fascia in df.fascia.unique():
        _pop = popolazione.loc[(popolazione.data==data)&(popolazione.fascia==fascia), "popolazione"].values[0]
        df.loc[(df.data==data)&(df.fascia==fascia), "totale"] = _pop
df["totale"] = df.totale.astype(int)

# %%
# calcolo percentuale di popolazione per data, fascia e stato vaccinale
df["percentuale_popolazione"] = df.popolazione / df.totale

# %%
# ordinamento per data e fascia
df.sort_values(by=["data", "fascia"], inplace=True)

# %%
# calcolo dei tassi per data, fascia e stato vaccinale
for y in ["diagnosi", "ricoveri", "intensive", "decessi"]:
    df[f"percentuale_{y}"] = df[y] / df.popolazione

# %%
# salvataggio report completo
df.to_csv("../reports_iss_vaccini.csv", index=False)

# %%
# controllo del file salvato
df_check = pd.read_csv(
    "../reports_iss_vaccini.csv",
    parse_dates=[
        "data", "pubblicazione", "popolazione_giorno",
        "diagnosi_start", "diagnosi_end",
        "ricoveri_start", "ricoveri_end",
        "intensive_start", "intensive_end",
        "decessi_start", "decessi_end"
    ]
)
df_check
# Out:
#           data pubblicazione  \
# 0   2021-07-14    2021-07-16
# 1   2021-07-14    2021-07-16
# 2   2021-07-14    2021-07-16
# 3   2021-07-14    2021-07-16
# 4   2021-07-14    2021-07-16
# ..         ...           ...
# 319 2021-12-15    2021-12-17
# 320 2021-12-15    2021-12-17
# 321 2021-12-15    2021-12-17
# 322 2021-12-15    2021-12-17
# 323 2021-12-15    2021-12-17
#
#                                                    url fascia  \
# 0    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 1    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 2    https://www.epicentro.iss.it/coronavirus/bolle...  12-39
# 3    https://www.epicentro.iss.it/coronavirus/bolle...  40-59
# 4    https://www.epicentro.iss.it/coronavirus/bolle...  40-59
# ..                                                 ...    ...
# 319  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 320  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 321  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 322  https://www.epicentro.iss.it/coronavirus/bolle...    80+
# 323  https://www.epicentro.iss.it/coronavirus/bolle...    80+
#
#                                      vaccino  popolazione  diagnosi  ricoveri  \
# 0                              non vaccinati     14011891     13549       513
# 1                       vaccinati incompleto      1815895      1243        11
# 2                         vaccinati completo      1607769       528         4
# 3                              non vaccinati      9340510      5747       779
# 4                       vaccinati incompleto      5502988      1586        51
# ..                                       ...          ...       ...       ...
# 319                            non vaccinati       216424      2786       847
# 320                     vaccinati incompleto        82183       302        91
# 321             vaccinati completo <= 5 mesi       335458       858       219
# 322              vaccinati completo > 5 mesi      2385897      9245      1919
# 323  vaccinati completo + aggiuntiva/booster      1549747      1485       100
#
#      intensive  decessi  ... intensive_start intensive_end decessi_start  \
# 0           13        7  ...      2021-06-04    2021-07-04    2021-05-21
# 1            0        1  ...      2021-06-04    2021-07-04    2021-05-21
# 2            0        0  ...      2021-06-04    2021-07-04    2021-05-21
# 3           66       45  ...      2021-06-04    2021-07-04    2021-05-21
# 4            3        4  ...      2021-06-04    2021-07-04    2021-05-21
# ..         ...      ...  ...             ...           ...           ...
# 319         48      345  ...      2021-10-29    2021-11-28    2021-10-22
# 320          2       23  ...      2021-10-29    2021-11-28    2021-10-22
# 321         13       89  ...      2021-10-29    2021-11-28    2021-10-22
# 322         64      582  ...      2021-10-29    2021-11-28    2021-10-22
# 323          4       20  ...      2021-10-29    2021-11-28    2021-10-22
#
#     decessi_end    totale percentuale_popolazione percentuale_diagnosi  \
# 0    2021-06-20  17435555                0.803639             0.000967
# 1    2021-06-20  17435555                0.104149             0.000685
# 2    2021-06-20  17435555                0.092212             0.000328
# 3    2021-06-20  18447460                0.506330             0.000615
# 4    2021-06-20  18447460                0.298306             0.000288
# ..          ...       ...                     ...                  ...
# 319  2021-11-21   4569709                0.047361             0.012873
# 320  2021-11-21   4569709                0.017984             0.003675
# 321  2021-11-21   4569709                0.073409             0.002558
# 322  2021-11-21   4569709                0.522111             0.003875
# 323  2021-11-21   4569709                0.339135             0.000958
#
#     percentuale_ricoveri percentuale_intensive  percentuale_decessi
# 0               0.000037          9.277834e-07         4.995757e-07
# 1               0.000006          0.000000e+00         5.506926e-07
# 2               0.000002          0.000000e+00         0.000000e+00
# 3               0.000083          7.065995e-06         4.817724e-06
# 4               0.000009          5.451584e-07         7.268778e-07
# ..                   ...                   ...                  ...
# 319             0.003914          2.217869e-04         1.594093e-03
# 320             0.001107          2.433593e-05         2.798632e-04
# 321             0.000653          3.875299e-05         2.653089e-04
# 322             0.000804          2.682429e-05         2.439334e-04
# 323             0.000065          2.581066e-06         1.290533e-05
#
# [324 rows x 25 columns]

# %%
df_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   data                     324 non-null    datetime64[ns]
#  1   pubblicazione            324 non-null    datetime64[ns]
#  2   url                      324 non-null    object
#  3   fascia                   324 non-null    object
#  4   vaccino                  324 non-null    object
#  5   popolazione              324 non-null    int64
#  6   diagnosi                 324 non-null    int64
#  7   ricoveri                 324 non-null    int64
#  8   intensive                324 non-null    int64
#  9   decessi                  324 non-null    int64
#  10  popolazione_giorno       324 non-null    datetime64[ns]
#  11  diagnosi_start           324 non-null    datetime64[ns]
#  12  diagnosi_end             324 non-null    datetime64[ns]
#  13  ricoveri_start           324 non-null    datetime64[ns]
#  14  ricoveri_end             324 non-null    datetime64[ns]
#  15  intensive_start          324 non-null    datetime64[ns]
#  16  intensive_end            324 non-null    datetime64[ns]
#  17  decessi_start            324 non-null    datetime64[ns]
#  18  decessi_end              324 non-null    datetime64[ns]
#  19  totale                   324 non-null    int64
#  20  percentuale_popolazione  324 non-null    float64
#  21  percentuale_diagnosi     324 non-null    float64
#  22  percentuale_ricoveri     324 non-null    float64
#  23  percentuale_intensive    324 non-null    float64
#  24  percentuale_decessi      324 non-null    float64
# dtypes: datetime64[ns](11), float64(5), int64(6), object(3)
# memory usage: 63.4+ KB
